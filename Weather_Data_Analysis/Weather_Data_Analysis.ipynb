# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"1. Weather Data.csv")
df=pd.DataFrame(data)
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df['Date/Time']=pd.to_datetime(df['Date/Time'])
# df.plot()

df[['Date/Time','Temp_C']].plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
df[df['Temp_C']==15].shape
# Out:
# (20, 8)

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
df.Weather.unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
df.nunique().count()
# Out:
# 8

# %%
df.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
df['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
df['Wind Speed_km/h'].value_counts()
# Out:
# 9     830
# 11    791
# 13    735
# 15    719
# 7     677
# 17    666
# 19    616
# 6     609
# 20    496
# 4     474
# 22    439
# 24    374
# 0     309
# 26    242
# 28    205
# 30    161
# 32    139
# 33     85
# 35     53
# 37     45
# 39     24
# 41     22
# 44     14
# 48     13
# 43     13
# 46     11
# 52      7
# 57      5
# 50      4
# 2       2
# 70      1
# 54      1
# 83      1
# 63      1
# Name: Wind Speed_km/h, dtype: int64

# %%
df[df["Weather"]== 'Clear']
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 114     1/5/2012 18:00    -7.1             -14.4         56               11
# 115     1/5/2012 19:00    -9.2             -15.4         61                7
# 116     1/5/2012 20:00    -9.8             -15.7         62                9
# 117     1/5/2012 21:00    -9.0             -14.8         63               13
# ...                ...     ...               ...        ...              ...
# 8646   12/26/2012 6:00   -13.4             -14.8         89                4
# 8698  12/28/2012 10:00    -6.1              -8.6         82               19
# 8713   12/29/2012 1:00   -11.9             -13.6         87               11
# 8714   12/29/2012 2:00   -11.8             -13.1         90               13
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
#       Visibility_km  Press_kPa Weather
# ...

# %%
df.isnull()
# Out:
#       Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0         False   False             False      False            False
# 1         False   False             False      False            False
# 2         False   False             False      False            False
# 3         False   False             False      False            False
# 4         False   False             False      False            False
# ...         ...     ...               ...        ...              ...
# 8779      False   False             False      False            False
# 8780      False   False             False      False            False
# 8781      False   False             False      False            False
# 8782      False   False             False      False            False
# 8783      False   False             False      False            False
#
#       Visibility_km  Press_kPa  Weather
# 0             False      False    False
# 1             False      False    False
# ...

# %%
s=df.rename(columns={"Weather":"Weather Condition"} , inplace=True)

df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather Condition'],
#       dtype='object')

# %%
df.Press_kPa.std()
# Out:
# 0.8440047459486483

# %%
df.Press_kPa.var()
# Out:
# 0.7123440111838423

# %%
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa     Weather Condition
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df[df['Weather Condition'].str.contains('Snow')].value_counts()
# Out:
# Date/Time         Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  Press_kPa  Weather Condition
# 1/10/2012 1:00     2.3    -3.4              66         35               25.0           100.28     Snow                         1
# 12/30/2012 3:00   -9.1    -10.4             90         11               3.6            100.30     Snow,Fog                     1
# 12/31/2012 9:00   -8.1    -9.6              89         4                2.4            101.09     Snow                         1
# 12/5/2012 10:00    2.1    -1.8              75         28               19.3           101.09     Rain Showers,Snow Showers    1
# 12/5/2012 11:00    2.2    -2.5              71         30               24.1           101.17     Snow Showers                 1
#                                                                                                                               ..
# ...

# %%
pd.pivot_table(df,index=["Weather Condition"])
# Out:
#                                          Dew Point Temp_C   Press_kPa  \
# Weather Condition
# Clear                                            0.089367  101.587443
# Cloudy                                           2.375810  100.911441
# Drizzle                                          5.504878  100.435366
# Drizzle,Fog                                      7.033750  100.786625
# Drizzle,Ice Pellets,Fog                         -0.700000  100.790000
# Drizzle,Snow                                     0.150000  100.890000
# Drizzle,Snow,Fog                                 0.120000   99.281333
# Fog                                              3.159333  101.184067
# Freezing Drizzle                                -8.000000  100.202857
# Freezing Drizzle,Fog                            -4.183333  100.441667
# Freezing Drizzle,Haze                           -8.000000  100.316667
# Freezing Drizzle,Snow                           -7.072727  100.520909
# ...

# %%
pd.pivot_table(df,index=["Weather Condition"],aggfunc='min')
# Out:
#                                                 Date/Time  Dew Point Temp_C  \
# Weather Condition
# Clear                                      1/11/2012 1:00             -28.5
# Cloudy                                     1/1/2012 17:00             -26.8
# Drizzle                                   1/23/2012 21:00              -0.2
# Drizzle,Fog                               1/23/2012 20:00              -1.6
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00              -0.7
# Drizzle,Snow                             12/17/2012 15:00               0.1
# Drizzle,Snow,Fog                         12/18/2012 21:00              -0.1
# Fog                                         1/1/2012 0:00             -17.2
# Freezing Drizzle                          1/13/2012 10:00             -12.2
# Freezing Drizzle,Fog                        1/1/2012 2:00              -9.0
# Freezing Drizzle,Haze                      2/1/2012 11:00              -8.3
# ...

# %%
pd.pivot_table(df,index=["Weather Condition"],aggfunc='max')
# Out:
#                                                 Date/Time  Dew Point Temp_C  \
# Weather Condition
# Clear                                       9/9/2012 5:00              20.4
# Cloudy                                     9/9/2012 23:00              22.6
# Drizzle                                    9/30/2012 3:00              17.7
# Drizzle,Fog                                9/30/2012 2:00              19.1
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00              -0.7
# Drizzle,Snow                             12/19/2012 18:00               0.2
# Drizzle,Snow,Fog                          12/22/2012 3:00               0.6
# Fog                                        9/22/2012 0:00              19.6
# Freezing Drizzle                            2/1/2012 5:00              -3.3
# Freezing Drizzle,Fog                      12/10/2012 5:00              -2.3
# Freezing Drizzle,Haze                      2/1/2012 13:00              -7.7
# ...

# %%
df['Date/Time'].dtype
# Out:
# dtype('O')
