# %% [markdown]
# # **Downlaoding Necessary Packages**

# %%
# !pip install neattext         #installing neatext package for text cleaing
# !pip install vadersentiment   #installing famous NLTK model for Sentiment Anlaysis
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting neattext
#   Downloading neattext-0.1.3-py3-none-any.whl (114 kB)
#      |████████████████████████████████| 114 kB 6.9 MB/s
# Installing collected packages: neattext
# Successfully installed neattext-0.1.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting vadersentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 8.2 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from vadersentiment) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->vadersentiment) (2022.5.18.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->vadersentiment) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->vadersentiment) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->vadersentiment) (1.24.3)
# Installing collected packages: vadersentiment
# Successfully installed vadersentiment-3.3.2

# %% [markdown]
# # **Importing Dependencies for the Project**

# %%
import numpy as np                           #python package for dealing with arrays
import pandas as pd                          #python package for data analysis
#python packages for data visualization
import seaborn as sns 
import plotly.express as px
import matplotlib.pyplot as plt
import neattext as nt                       #python package for text cleaning
import spacy                                #premium python package for text analysis
nlp=spacy.load("en_core_web_sm")            #importing spacy small model that helps in text analysis

# Setting environment to ignore future warnings
import warnings
warnings.simplefilter('ignore')

# Changing default pandas setting to custom
from matplotlib.pylab import rcParams
rcParams["figure.figsize"] = (14, 7)
pd.set_option('max_columns', 30)
pd.set_option('max_rows', 20)
# %matplotlib inline

# %% [markdown]
# # **Reading the Data Using Google Colab**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-832e19f2-0e0d-4caa-abd2-1afd57272456" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-832e19f2-0e0d-4caa-abd2-1afd57272456">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Women's_Clothing_E-Commerce_Reviews.xlsx to Women's_Clothing_E-Commerce_Reviews.xlsx

# %% [markdown]
# # **Converting Data into Tabular form for Analysis**

# %%
import io
women_df= pd.read_excel(io.BytesIO(uploaded['Women\'s_Clothing_E-Commerce_Reviews.xlsx']))

# %% [markdown]
# # **Sample of the Data**

# %%
women_df.head(3)
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
#
#    Positive Feedback Count Division Name Department Name Class Name
# 0                        0     Initmates        Intimate  Intimates
# 1                        4       General         Dresses    Dresses
# 2                        0       General         Dresses    Dresses

# %% [markdown]
# # **Shape of the Data**

# %%
women_df.shape
# rows=23486
# columns=11
# Out:
# (23486, 11)

# %% [markdown]
# # **Percentaged of Missing Values in the Data**

# %%
missing_percent = women_df.isna().sum(axis=0)
missing_percent = missing_percent/women_df.shape[0]
missing_percent.plot(kind='bar',title = 'Missing Value Columns',ylabel = '% missing', ylim = (0,1.01),grid = True)

# %%
# percentage of null values are very small to that we can remove them

# %% [markdown]
# # **Removing Null Values**

# %%
women_df=women_df.dropna(axis=0)

# %%
women_df.isnull().sum()
# Out:
# Unnamed: 0                 0
# Clothing ID                0
# Age                        0
# Title                      0
# Review Text                0
# Rating                     0
# Recommended IND            0
# Positive Feedback Count    0
# Division Name              0
# Department Name            0
# Class Name                 0
# dtype: int64

# %% [markdown]
# # **Generalize Code for Various Visualizations**

# %%
def make_plots(feature, title="", limited=False, n=10):
    # print("Total unique values are: ", len(feature.value_counts()), "\n\n")
    # print("Category\tValue\n")
    if limited:
        data = feature.value_counts()[0:n]
    else:
        data = feature.value_counts()
    # print(data)
    categories_num = len(data)
    #plotting bar-plot and pie chart
    # sns.set_style('darkgrid')
    plt.figure(figsize=(26,5))
    plt.subplot(1,2,1)
    plt.title(title, fontsize=16)
    plt.xticks(rotation=45)
    plot = sns.barplot(x=data.index, y=data.values, edgecolor="white", palette=sns.palettes.color_palette("icefire"))
    total = len(feature)
    for p in plot.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() / 2 - 0.08
        y = p.get_y() + p.get_height()
        plot.annotate(percentage, (x, y), size = 12)
    
    plt.subplot(1,2,2)
    labels = data.index
    plt.pie(x=data, autopct="%.1f%%", explode=[0.02]*categories_num, labels=labels, pctdistance=0.5)
    plt.title(title, fontsize=16)
    plt.show()

# %% [markdown]
# # **Age Distribution**

# %%
plt.figure(figsize=(25,5))
sns.countplot(x = 'Age', data = women_df,order = women_df['Age'].value_counts().index)
plt.title("Buyer by Age Distribution")
plt.show()

# %%
#our store is targeting people of age 19 to 80+; Our most of sellings are to people age of between 30-50. It means our products are mostly utilized by Adults.
#if someone wants to increase its sales he/should focus on teens and people below 30. The reason is that people of these age groups have more buying potential.

# %% [markdown]
# # **Majority of the Products are Recommended by Customers of all Age Groups**

# %%
sns.catplot(x="Department Name", y="Age", hue="Recommended IND",data= women_df)
plt.show()
#this visualization is telling that in each department we have significant number of recommnedations by all the age gropus. This very good for our store. I think there is no
# improvement required here

# %% [markdown]
# # **Highly Recommended Products By Rating**

# %%
sns.catplot(x="Rating", y="Age", hue="Recommended IND",data= women_df)
plt.show()
# Here you can see that most of the recommendations by all the consumers to those products have 4-5 ratings. It is natural good products will be recommended. 
# The Store owners should focus on quality products and try to increase 5 stars rating.
# Products rated 1 and 2 are almost non-recommended by all the customers, while products rated 4 and 5 are nearly recommended by all the customers.

# %% [markdown]
# # **Which Department is Highly Recommended?**

# %%
plt.figure(figsize=(26,5))
sns.countplot(data=women_df, x='Class Name', hue='Recommended IND',  palette = "Set1")
plt.show()
#four classes "Dresses", "Pants","Blouese","Knits" have the highest recommendations among other departments. One who is wishing to increase its sales should pay attention
# to other departments, especially in the "Trend" class, today is the era of technology and everyone is in touch with one another. They try to follow  Trending items and dressed up
# according to current fashion. Age can be one factor for low sales in Trend Class

# %%
plt.figure(figsize=(26,5))
sns.countplot(data=women_df, x='Department Name', hue='Recommended IND' ,palette = "Dark2")
plt.show()

# %%
plt.figure(figsize=(25,5))
sns.countplot(data=women_df, x='Division Name', hue='Recommended IND', palette = "Set1")
plt.show()
# Intimate Division has the lowest recommendations as compared to other divisions. General Division stands out in this competition. One reason is most of our sellings are to people
# above age 30 and intimate products mostly used below 30. Due to less selling to below 30, these Intimate figures are short.

# %% [markdown]
# # **Most Sellings Department**

# %%
plt.figure(figsize = (25, 6))
plt.subplot(1, 2, 1)
sns.countplot(x = women_df['Department Name'], data = women_df)
plt.subplot(1, 2, 2)
plt.pie(x= women_df['Department Name'].value_counts(),labels=('Tops','Dresses',"Bottoms","Intimate","Jackets","Trend") ,explode = (0, 0.08, 0.01,0.02,0.2,0.2), shadow = True, autopct = '%1.2f%%')
plt.show()

#Tops deparments taking lead in selling point of view. "Bottoms" and "Dresses" come on position 2 and three. Most of our sales are in jewllery items.

# %%
make_plots(women_df['Rating'])
#here point of concern comes, about 55% produts are rated as 5-star and 21% as 4-star. 5 and 4 stars cover 76% of selling. This figure in not perfect for us.
# It would be 90% or above. Store owner have to review its products that delivering to customers and should enhance their quality and user experienence

# %% [markdown]
# # **Text Analysis**

# %%
import neattext as nt

# %%
def pre_cleaning(text):
    text=nt.fix_contractions(text)
    text=nt.remove_puncts(text)
    text=nt.remove_bad_quotes(text)
    text=nt.remove_emojis(text)
    text=nt.remove_numbers(text)
    text=nt.remove_accents(text)
    text=nt.remove_multiple_spaces(text)
    text=nt.remove_non_ascii(text)
    text=nt.remove_userhandles(text)
    return text

# %%
women_df['Pre_Cleaned_Reviews']=women_df['Review Text'].apply(lambda x:pre_cleaning(str(x)))

# %% [markdown]
# # **Sentiment Analysis**

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer  #package for sentiment analysis
sent_anal_obj=SentimentIntensityAnalyzer()

# %% [markdown]
# # **Calculating Sentiment Score (1,-1) [1, Extremely Postive] [-1, Extremely Negative]**

# %%
#method for calculating Sentiment Score
def sentiment_score(my_text):
  sentimnent_dict=sent_anal_obj.polarity_scores(str(my_text))
  return sentimnent_dict['compound']

# %%
women_df['Sentiment_Score']=women_df['Pre_Cleaned_Reviews'].apply(lambda x:sentiment_score(x))

# %% [markdown]
# ##Assigning Sentiment Tags [Sentiment Score >= 0.05(positive)] [Sentiment Score <= - 0.05(Negative)] [Remaing(Neutral)]

# %%
#method for assigning semtiment tag according to polarity
def sentiment_tag(polarity):
    if polarity >= 0.05 :
        return "Positive"
    elif polarity <= - 0.05:
        return "Negative"
    else:
        return "Neutral"

# %%
women_df['Sentiment Tag']=women_df['Sentiment_Score'].apply(lambda x:sentiment_tag(x))

# %%
make_plots(women_df['Sentiment Tag'],'Customers Sentiments')
#Stunning: Above 90% reviews are postive

# %% [markdown]
# # **Emotion of Customers on our Products**

# %%
! pip install transformers -q
from transformers import pipeline
emotion = pipeline('sentiment-analysis', model='arpanghoshal/EmoRoBERTa')   #downloading hugging face pre-trained model for emotions detection: It can detect 28 emotions
# Out:
#      |████████████████████████████████| 4.2 MB 7.8 MB/s
#      |████████████████████████████████| 86 kB 4.7 MB/s
#      |████████████████████████████████| 6.6 MB 38.0 MB/s
#      |████████████████████████████████| 596 kB 55.9 MB/s
# Downloading:   0%|          | 0.00/1.68k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/478M [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at arpanghoshal/EmoRoBERTa.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.
# Downloading:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/780k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]

# %%
women_df['Emotions']=women_df['Pre_Cleaned_Reviews'][0:100].apply(emotion)

# %%
def extract_em(em_dict):
  return em_dict[0]['label'] 
  # print(em_dict[0]['label'])

# %%
women_df['Emotions_Label']=women_df['Emotions'][0:100].apply(lambda x:extract_em(x))

# %% [markdown]
# # **Aspect Based Sentiment Analysis**

# %%
# code for finding aspect of customer review
def ABSA(text):
		doc=nlp(text)
		descriptive_term = ''
		target = ''
		for token in doc:
			if token.dep_ == 'nsubj' and token.pos_ == 'NOUN':
				target = token.text
			if token.pos_ == 'ADJ':
				prepend = ''
				for child in token.children:
					if child.pos_ != 'ADV':
						continue
					prepend += child.text + ' '
					descriptive_term = prepend + token.text
		return target+" "+descriptive_term

# %%
women_df['Aspects']=women_df['Pre_Cleaned_Reviews'][0:1000].apply(lambda x:ABSA(x))

# %%
def post_cleaning(text):
  text=nt.remove_stopwords(text)
  text=nt.remove_shortwords(text,3)
  return text

# %%
women_df['Post_Cleaned_Reviews']=women_df['Pre_Cleaned_Reviews'].apply(lambda x:post_cleaning(x))

# %%
# !pip install wordcloud
# !pip install colorama
# !pip install quarify
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.7/dist-packages (1.5.0)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from wordcloud) (1.21.6)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from wordcloud) (7.1.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (0.4.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement quarify (from versions: none)
# ERROR: No matching distribution found for quarify

# %%
from colorama import Fore, init, Back, Style   #dependencies for styling word clouds
from wordcloud import WordCloud   #package for creating word clouds
from statsmodels.graphics.mosaicplot import mosaic
# import squarify

# %% [markdown]
# # **Words used in Reviews of Specific Ratings**

# %%
around_color = "#f6f5f5"
inside_color= "#f6f5f5"
colors = sns.color_palette("ch:s=-.2,r=.6")
fig = plt.figure(figsize=(10,6))
colors = colors
# ax = plt.axes()

# %%
for ratings in range(0,5):
    values = sorted(women_df["Rating"].unique())
    specific_value= values[ratings]
    dataset = women_df[women_df["Rating"]==specific_value]
    list_ = dataset["Post_Cleaned_Reviews"].tolist()
    sentence = "".join(list_)
    plt.figure(figsize=(40,20))
    plt.subplot(1,5,1+ratings)
    plt.imshow(WordCloud().generate(sentence))
    plt.title("Words used in " + str(specific_value) + " rating", fontsize=30)
    plt.xticks([]);
    plt.yticks([]);
    fig.patch.set_facecolor(inside_color)
    ax.set_facecolor(around_color)

# %%
def create_age_groups(age):
    if age>0 and age<14:
        return "Children"
    elif age >=14 and age <24:
        return "Teen"
    elif age>=24 and age <64:
        return "Adult"
    else:
        return "Senior"

# %%
women_df["Age Group"]= women_df["Age"].apply(lambda x:create_age_groups(x))

# %% [markdown]
# # **Words used by Different Age Groups**

# %%
for age in range(0,3):
    unique_values = list(women_df["Age Group"].unique())
    specific_age = unique_values[age]
    dataset = women_df[women_df["Age Group"]==specific_age]
    age_list = dataset["Post_Cleaned_Reviews"].tolist()
    sentence = "".join(age_list)
    plt.figure(figsize=(30,15))
    plt.subplot(1,3,1+age)
    plt.imshow(WordCloud().generate(sentence))
    plt.title("Words used by " + str(specific_age), fontsize=30)
    plt.xticks([]);
    plt.yticks([]);
    fig.patch.set_facecolor(inside_color)
    ax.set_facecolor(around_color)

# %%
pd.set_option('display.max_rows', 100)

# %% [markdown]
# # **Final Results**

# %%
women_df[["Review Text","Sentiment Tag","Emotions_Label","Aspects"]].head(100)
# Out:
#                                            Review Text Sentiment Tag  \
# 2    I had such high hopes for this dress and reall...      Positive
# 3    I love, love, love this jumpsuit. it's fun, fl...      Positive
# 4    This shirt is very flattering to all due to th...      Positive
# 5    I love tracy reese dresses, but this one is no...      Positive
# 6    I aded this in my basket at hte last mintue to...      Positive
# 7    I ordered this in carbon for store pick up, an...      Negative
# 8    I love this dress. i usually get an xs but it ...      Positive
# 9    I'm 5"5' and 125 lbs. i ordered the s petite t...      Positive
# 10   Dress runs small esp where the zipper area run...      Positive
# 12   More and more i find myself reliant on the rev...      Positive
# 13   Bought the black xs to go under the larkspur m...      Positive
# 14   This is a nice choice for holiday gatherings. ...      Negative
# 15   I took these out of the package and wanted the...      Positive
# 16   Material and color is nice.  the leg opening i...      Positive
# 17   Took a chance on this blouse and so glad i did...      Positive
# 18   A flattering, super cozy coat.  will work well...      Positive
# 19   I love the look and feel of this tulle dress. ...      Positive
# 20   If this product was in petite, i would get the...      Positive
# 21   I'm upset because for the price of the dress, ...      Positive
# 22   First of all, this is not pullover styling. th...      Positive
# 23   Cute little dress fits tts. it is a little hig...      Positive
# 24   I love this shirt because when i first saw it,...      Positive
# 25   Loved the material, but i didnt really look at...      Positive
# 26   I have been waiting for this sweater coat to s...      Positive
# 27   The colors weren't what i expected either. the...      Positive
# 28   I have several of goodhyouman shirts and i get...      Positive
# 29   This sweater is so comfy and classic - it bala...      Positive
# 31   I never would have given these pants a second ...      Positive
# 32   These pants are even better in person. the onl...      Positive
# 33   I ordered this 3 months ago, and it finally ca...      Positive
# 34   This is such a neat dress. the color is great ...      Positive
# 35   Wouldn't have given them a second look but tri...      Positive
# 37   Just ordered this in a small for me (5'6", 135...      Positive
# 42   This poncho is so cute i love the plaid check ...      Positive
# 43   First, this is thermal ,so naturally i didn't ...      Positive
# 44   Tried this on today at my local retailer and h...      Positive
# 45   I bought this item from online... the fit on t...      Positive
# 48   This sweater is perfect for fall...it's roomy,...      Positive
# 49   Really cute top! the embroidery on the collar ...      Positive
# 50   This is a cute top that can transition easily ...      Positive
# 51   I absolutely love this bib tee! it's probably ...      Positive
# 53   Very soft and comfortable. the shirt has an un...      Positive
# 54   Nice top. armholes are a bit oversized but as ...      Positive
# 55   This is an adorable top that i find to be extr...      Positive
# 57   This tank fit well and i loved the ruffle in t...      Positive
# 59   I've been looking for bralettes that provide s...      Positive
# 60   This dress is simply beautiful and stunning. i...      Positive
# 61   3 tags sewn in, 2 small (about 1'' long) and 1...      Negative
# 62   I recently got this on sale after looking at i...      Positive
# 63   Very comfortable shirt, light weight top with ...      Positive
# 64   Loved this top and was really happy to find it...      Positive
# 66   Just received this in the mail, tried it on an...      Positive
# 67   Love this top! i kept eyeing it online and wav...      Positive
# 68   I really loved this top online and wanted to l...      Positive
# 69   I really wanted this to work. alas, it had a s...      Positive
# 70   This top is so cute, but it is massively babyd...      Positive
# 71   Why do designers keep making crop tops??!! i c...      Positive
# 72   I have a short torso and this works well for m...      Positive
# 75   I am so drawn to baby doll and boxy shirts so ...      Positive
# 76   I would have loved this dress if the bust and ...      Positive
# 77   The zipper broke on this piece the first time ...      Negative
# 78   I usually size up with this brand. small was p...      Positive
# 79   This dress is adorable - it's a perfect casual...      Positive
# 80   I am usually a petite 6 but since this dress d...      Positive
# 82   The rest of the reviewers are right about the ...      Positive
# 83   I purchased this top in an antro store last we...      Positive
# 84   I received this shirt in my typical xs and it ...      Positive
# 86   I tried this on from the sale section, and the...      Positive
# 87   I debated n that as i think it looks loose on ...      Positive
# 88   Really cute piece, but it's huge. i ordered an...      Negative
# 89   I bought this top online in the burnt orange c...      Positive
# 90   I love cute summer dresses and this one, espec...      Positive
# 94   This shirt caught my eye because of how beauti...      Positive
# 95   Purchased this top online, and when i received...      Positive
# 97   I was very excited to order this top in red xs...      Positive
# 99   I am in need of easy comfortable tops for ever...      Positive
# 100  At first i wasn't sure about it. the neckline ...      Positive
# 101  I find that this brand can be a little bit all...      Positive
# 102  This top is absolutely stunning. i purchased t...      Positive
# 103  The fabric felt cheap and i didn't find it to ...      Positive
# 105  I bought this lovely silk/velvet shirt in the ...      Positive
# 106  Was so excited to order this beautiful shirt! ...      Positive
# 107  I ordered ivory in xl because this brand tends...      Positive
# 108  The shirt is exactly as it is pictured, i have...      Positive
# 110  This is so thin and poor quality. especially f...      Negative
# 111  I didn't end up keeping this dress...it just w...      Positive
# 112  I read the first review on this and ordered bo...      Positive
# 113  This dress is comfortable and stylish at the s...      Positive
# 114  The design/shape of the dress are quite flatte...      Negative
# 115  This one totally worked for me. love the color...      Positive
# 116  Prior reviewer nailed it with the summary of t...      Positive
# 118  First, the fabric is beautiful and lovely for ...      Positive
# 119  The color is perfect for fall and into winter....      Positive
# 120  The perfect striped t-shirt, and the cute litt...      Positive
# 123  After reading the previous reviews, i ordered ...      Positive
# 124  I was so excited to try out this top since it ...      Positive
# 125  Like others reviewers mentioned on here, this ...      Positive
# 128  Nice vest, pretty olive color, hangs nice but....      Positive
# 129  This top is super comfy and casual. the slit/d...      Positive
# 131  It's ok, fit doesn't wow me because of my body...      Positive
#
#      Emotions_Label                         Aspects
# 2       nervousness             flaw somewhat cheap
# 3              love
# 4              love           shirt very flattering
# 5              love                 skirt very full
# 6        admiration           color really gorgeous
# 7           neutral              sleeves also loose
# 8              love                 very flattering
# 9              love                tulle less busty
# 10   disappointment        area pretty disappointed
# 12       admiration                very formfitting
# 13       admiration              straps very pretty
# 14             love                 fabrics too big
# 15              joy                      very happy
# 16      disapproval               length very large
# 17       admiration        launders perfectly crisp
# 18         approval                           coat
# 19             love                         length
# 20          neutral               medium back front
# 21   disappointment            quality pretty poofy
# 22          sadness                           slip
# 23             love                          dress
# 24             love
# 25             love                dress much wider
# 26       excitement               sleeves even more
# 27      disapproval              skirt more vibrant
# 28        gratitude                  kisses so many
# 29       admiration        others still enough thin
# 31             love           brand more flattering
# 32      disapproval            downside even better
# 33   disappointment             quality still worth
# 34       admiration               length super cute
# 35             love
# 37       admiration                 ageappropriate
# 42             love                  colors so cute
# 43             love                    really sheer
# 44         approval                 ruching too bad
# 45       admiration
# 48             love                          color
# 49       admiration       embroidery super adorable
# 50             love                 color well nice
# 51             love
# 53             love                  neck very soft
# 54       admiration                  summer so many
# 55       admiration              medium so feminine
# 57             love                          front
# 59           desire        downside more supportive
# 60       admiration          dress simply beautiful
# 61             love                    one so itchy
# 62              joy         pattern very flattering
# 63             love            top very comfortable
# 64              joy                    really happy
# 66              joy                    very similar
# 67             love                  body very soft
# 68             love                       neckline
# 69             love                         fabric
# 70       admiration               fabric so natural
# 71      disapproval              pattern super tall
# 72          neutral                         fabric
# 75       admiration              picture super cute
# 76             love                material too big
# 77   disappointment              very disappointing
# 78       admiration                            top
# 79       admiration        size somewhat adjustable
# 80       admiration           dress so overwhelming
# 82             love                 tie a14ber cute
# 83       admiration              blouse very unique
# 84         optimism                          slits
# 86         surprise            torso almost neutral
# 87         approval                         as good
# 88       admiration                  extremely wide
# 89       excitement                 front too short
# 90             love       material quite flattering
# 94       admiration             shirt how beautiful
# 95       admiration             browni very pleased
# 97       excitement                         so cute
# 99         approval          shirt slightly too big
# 100     realization             neckline much lower
# 101      admiration                          shirt
# 102      admiration                 top very unique
# 103     disapproval                   measurements
# 105  disappointment
# 106      admiration            saidit way too short
# 107            love               brand really long
# 108            love                          shirt
# 110     disapproval                 buttons so thin
# 111            love              part just too high
# 112        approval          shoulders comfy casual
# 113        approval                          dress
# 114     disapproval           one very disappointed
# 115            love                            one
# 116      admiration
# 118      admiration                 cut very narrow
# 119             joy                fabric even more
# 120            love                            one
# 123      admiration                    so beautiful
# 124      excitement                shape so excited
# 125      admiration                   part so large
# 128      admiration          color just kinda funny
# 129      admiration              design super comfy
# 131        approval  point especially nonflattering
